# %%
import psycopg2, warnings
import pandas as pd
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

# %% [markdown]
# # **Connect to database**

# %%
conn = psycopg2.connect(
    host="localhost",
    database="WorldCup",
    user="guane",
    password="tu_password",
    port="5432"
)

print("Conectado")
# Out:
# Conectado

# %%
cursor = conn.cursor()

cursor.execute("SELECT * FROM world_cup_matches_raw LIMIT 10;")

print(cursor.fetchone())
# Out:
# ('1930', '13 Jul 1930 - 15:00 ', 'Group 1', 'Pocitos', 'Montevideo ', 'France', '4', '1', 'Mexico', ' ', '4444.0', '3', '0', 'LOMBARDI Domingo (URU)', 'CRISTOPHE Henry (BEL)', 'REGO Gilberto (BRA)', '201', '1096', 'FRA', 'MEX')

# %% [markdown]
# # **Queries**

# %%
query = """
SELECT *
FROM world_cup_matches_raw
LIMIT 10
"""

df = pd.read_sql(query, conn)

df
# Out:
#    year              datetime    stage             stadium         city  \
# 0  1930  13 Jul 1930 - 15:00   Group 1             Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4      Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2      Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3             Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1      Parque Central  Montevideo
# 5  1930  16 Jul 1930 - 14:45   Group 1      Parque Central  Montevideo
# 6  1930  17 Jul 1930 - 12:45   Group 2      Parque Central  Montevideo
# 7  1930  17 Jul 1930 - 14:45   Group 4      Parque Central  Montevideo
# 8  1930  18 Jul 1930 - 14:30   Group 3  Estadio Centenario  Montevideo
# 9  1930  19 Jul 1930 - 12:50   Group 1  Estadio Centenario  Montevideo
#
#   hometeamname hometeamgoals awayteamgoals awayteamname winconditions  \
# 0       France             4             1       Mexico
# 1          USA             3             0      Belgium
# 2   Yugoslavia             2             1       Brazil
# 3      Romania             3             1         Peru
# 4    Argentina             1             0       France
# 5        Chile             3             0       Mexico
# 6   Yugoslavia             4             0      Bolivia
# 7          USA             3             0     Paraguay
# 8      Uruguay             1             0         Peru
# 9        Chile             1             0       France
#
#   attendance halftimehomegoals halftimeawaygoals                   referee  \
# 0     4444.0                 3                 0    LOMBARDI Domingo (URU)
# 1    18346.0                 2                 0         MACIAS Jose (ARG)
# 2    24059.0                 2                 0       TEJADA Anibal (URU)
# 3     2549.0                 1                 0     WARNKEN Alberto (CHI)
# 4    23409.0                 0                 0       REGO Gilberto (BRA)
# 5     9249.0                 1                 0     CRISTOPHE Henry (BEL)
# 6    18306.0                 0                 0  MATEUCCI Francisco (URU)
# 7    18306.0                 2                 0         MACIAS Jose (ARG)
# 8    57735.0                 0                 0       LANGENUS Jean (BEL)
# 9     2000.0                 0                 0       TEJADA Anibal (URU)
#
#                  assistant1                  assistant2 roundid matchid  \
# 0     CRISTOPHE Henry (BEL)         REGO Gilberto (BRA)     201    1096
# 1  MATEUCCI Francisco (URU)       WARNKEN Alberto (CHI)     201    1090
# 2   VALLARINO Ricardo (URU)         BALWAY Thomas (FRA)     201    1093
# 3       LANGENUS Jean (BEL)    MATEUCCI Francisco (URU)     201    1098
# 4      SAUCEDO Ulises (BOL)  RADULESCU Constantin (ROU)     201    1085
# 5   APHESTEGUY Martin (URU)         LANGENUS Jean (BEL)     201    1095
# 6    LOMBARDI Domingo (URU)       WARNKEN Alberto (CHI)     201    1092
# 7   APHESTEGUY Martin (URU)         TEJADA Anibal (URU)     201    1097
# 8       BALWAY Thomas (FRA)       CRISTOPHE Henry (BEL)     201    1099
# 9    LOMBARDI Domingo (URU)         REGO Gilberto (BRA)     201    1094
#
#   hometeaminitials awayteaminitials
# 0              FRA              MEX
# 1              USA              BEL
# 2              YUG              BRA
# 3              ROU              PER
# 4              ARG              FRA
# 5              CHI              MEX
# 6              YUG              BOL
# 7              USA              PAR
# 8              URU              PER
# 9              CHI              FRA

# %%
def get_matches_by_year(year):

    query = """
    SELECT *
    FROM world_cup_matches_raw
    WHERE year = %s
    """

    return pd.read_sql(
        query,
        conn,
        params=(str(year),)
    )

# %%
get_matches_by_year(1930)
# Out:
#     year              datetime        stage             stadium         city  \
# 0   1930  13 Jul 1930 - 15:00       Group 1             Pocitos  Montevideo
# 1   1930  13 Jul 1930 - 15:00       Group 4      Parque Central  Montevideo
# 2   1930  14 Jul 1930 - 12:45       Group 2      Parque Central  Montevideo
# 3   1930  14 Jul 1930 - 14:50       Group 3             Pocitos  Montevideo
# 4   1930  15 Jul 1930 - 16:00       Group 1      Parque Central  Montevideo
# 5   1930  16 Jul 1930 - 14:45       Group 1      Parque Central  Montevideo
# 6   1930  17 Jul 1930 - 12:45       Group 2      Parque Central  Montevideo
# 7   1930  17 Jul 1930 - 14:45       Group 4      Parque Central  Montevideo
# 8   1930  18 Jul 1930 - 14:30       Group 3  Estadio Centenario  Montevideo
# 9   1930  19 Jul 1930 - 12:50       Group 1  Estadio Centenario  Montevideo
# 10  1930  19 Jul 1930 - 15:00       Group 1  Estadio Centenario  Montevideo
# 11  1930  20 Jul 1930 - 13:00       Group 2  Estadio Centenario  Montevideo
# 12  1930  20 Jul 1930 - 15:00       Group 4  Estadio Centenario  Montevideo
# 13  1930  21 Jul 1930 - 14:50       Group 3  Estadio Centenario  Montevideo
# 14  1930  22 Jul 1930 - 14:45       Group 1  Estadio Centenario  Montevideo
# 15  1930  26 Jul 1930 - 14:45   Semi-finals  Estadio Centenario  Montevideo
# 16  1930  27 Jul 1930 - 14:45   Semi-finals  Estadio Centenario  Montevideo
# 17  1930  30 Jul 1930 - 14:15         Final  Estadio Centenario  Montevideo
#
#    hometeamname hometeamgoals awayteamgoals awayteamname winconditions  \
# 0        France             4             1       Mexico
# 1           USA             3             0      Belgium
# 2    Yugoslavia             2             1       Brazil
# 3       Romania             3             1         Peru
# 4     Argentina             1             0       France
# 5         Chile             3             0       Mexico
# 6    Yugoslavia             4             0      Bolivia
# 7           USA             3             0     Paraguay
# 8       Uruguay             1             0         Peru
# 9         Chile             1             0       France
# 10    Argentina             6             3       Mexico
# 11       Brazil             4             0      Bolivia
# 12     Paraguay             1             0      Belgium
# 13      Uruguay             4             0      Romania
# 14    Argentina             3             1        Chile
# 15    Argentina             6             1          USA
# 16      Uruguay             6             1   Yugoslavia
# 17      Uruguay             4             2    Argentina
#
#    attendance halftimehomegoals halftimeawaygoals                   referee  \
# 0      4444.0                 3                 0    LOMBARDI Domingo (URU)
# 1     18346.0                 2                 0         MACIAS Jose (ARG)
# 2     24059.0                 2                 0       TEJADA Anibal (URU)
# 3      2549.0                 1                 0     WARNKEN Alberto (CHI)
# 4     23409.0                 0                 0       REGO Gilberto (BRA)
# 5      9249.0                 1                 0     CRISTOPHE Henry (BEL)
# 6     18306.0                 0                 0  MATEUCCI Francisco (URU)
# 7     18306.0                 2                 0         MACIAS Jose (ARG)
# 8     57735.0                 0                 0       LANGENUS Jean (BEL)
# 9      2000.0                 0                 0       TEJADA Anibal (URU)
# 10    42100.0                 3                 1      SAUCEDO Ulises (BOL)
# 11    25466.0                 1                 0       BALWAY Thomas (FRA)
# 12    12000.0                 1                 0   VALLARINO Ricardo (URU)
# 13    70022.0                 4                 0       REGO Gilberto (BRA)
# 14    41459.0                 2                 1       LANGENUS Jean (BEL)
# 15    72886.0                 1                 0       LANGENUS Jean (BEL)
# 16    79867.0                 3                 1       REGO Gilberto (BRA)
# 17    68346.0                 1                 2       LANGENUS Jean (BEL)
#
#                   assistant1                  assistant2 roundid matchid  \
# 0      CRISTOPHE Henry (BEL)         REGO Gilberto (BRA)     201    1096
# 1   MATEUCCI Francisco (URU)       WARNKEN Alberto (CHI)     201    1090
# 2    VALLARINO Ricardo (URU)         BALWAY Thomas (FRA)     201    1093
# 3        LANGENUS Jean (BEL)    MATEUCCI Francisco (URU)     201    1098
# 4       SAUCEDO Ulises (BOL)  RADULESCU Constantin (ROU)     201    1085
# 5    APHESTEGUY Martin (URU)         LANGENUS Jean (BEL)     201    1095
# 6     LOMBARDI Domingo (URU)       WARNKEN Alberto (CHI)     201    1092
# 7    APHESTEGUY Martin (URU)         TEJADA Anibal (URU)     201    1097
# 8        BALWAY Thomas (FRA)       CRISTOPHE Henry (BEL)     201    1099
# 9     LOMBARDI Domingo (URU)         REGO Gilberto (BRA)     201    1094
# 10    ALONSO Gualberto (URU)  RADULESCU Constantin (ROU)     201    1086
# 11  MATEUCCI Francisco (URU)        VALLEJO Gaspar (MEX)     201    1091
# 12         MACIAS Jose (ARG)      LOMBARDI Domingo (URU)     201    1089
# 13     WARNKEN Alberto (CHI)        SAUCEDO Ulises (BOL)     201    1100
# 14     CRISTOPHE Henry (BEL)        SAUCEDO Ulises (BOL)     201    1084
# 15      VALLEJO Gaspar (MEX)       WARNKEN Alberto (CHI)     202    1088
# 16      SAUCEDO Ulises (BOL)         BALWAY Thomas (FRA)     202    1101
# 17      SAUCEDO Ulises (BOL)       CRISTOPHE Henry (BEL)     405    1087
#
#    hometeaminitials awayteaminitials
# 0               FRA              MEX
# 1               USA              BEL
# 2               YUG              BRA
# 3               ROU              PER
# 4               ARG              FRA
# 5               CHI              MEX
# 6               YUG              BOL
# 7               USA              PAR
# 8               URU              PER
# 9               CHI              FRA
# 10              ARG              MEX
# 11              BRA              BOL
# 12              PAR              BEL
# 13              URU              ROU
# 14              ARG              CHI
# 15              ARG              USA
# 16              URU              YUG
# 17              URU              ARG

# %%
query = """
SELECT
    year,
    COUNT(*) AS matches
FROM world_cup_matches_raw
GROUP BY year
ORDER BY year
"""

df = pd.read_sql(query, conn)

df
# Out:
#     year  matches
# 0   1930       18
# 1   1934       17
# 2   1938       18
# 3   1950       22
# 4   1954       26
# 5   1958       35
# 6   1962       32
# 7   1966       32
# 8   1970       32
# 9   1974       38
# 10  1978       38
# 11  1982       52
# 12  1986       52
# 13  1990       52
# 14  1994       52
# 15  1998       64
# 16  2002       64
# 17  2006       64
# 18  2010       64
# 19  2014       64

# %%
df.plot(
    x="year",
    y="matches",
    kind="bar"
)

plt.show()

# %% [markdown]
# # **PROOF API**

# %%
import requests

BASE_URL = "http://127.0.0.1:8000"

# 1) Verificar que la API este activa
health_response = requests.get(f"{BASE_URL}/health", timeout=10)
print("/health ->", health_response.status_code, health_response.json())

# 2) Probar consulta de partidos
matches_response = requests.get(
    f"{BASE_URL}/matches",
    params={"limit": 5, "offset": 0},
    timeout=10,
)
print("/matches ->", matches_response.status_code)

if matches_response.ok:
    data = matches_response.json()
    print("Registros recibidos:", len(data))
    if data:
        print("Primer registro:")
        print(data[0])
else:
    print(matches_response.text)
# Out:
# /health -> 200 {'status': 'ok'}
# /matches -> 200
# Registros recibidos: 5
# Primer registro:
# {'year': '1930', 'datetime': '13 Jul 1930 - 15:00 ', 'stage': 'Group 4', 'stadium': 'Parque Central', 'city': 'Montevideo ', 'hometeamname': 'USA', 'hometeamgoals': '3', 'awayteamgoals': '0', 'awayteamname': 'Belgium', 'winconditions': ' ', 'attendance': '18346.0', 'halftimehomegoals': '2', 'halftimeawaygoals': '0', 'referee': 'MACIAS Jose (ARG)', 'assistant1': 'MATEUCCI Francisco (URU)', 'assistant2': 'WARNKEN Alberto (CHI)', 'roundid': '201', 'matchid': '1090', 'hometeaminitials': 'USA', 'awayteaminitials': 'BEL'}
